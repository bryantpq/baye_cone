# %%
# Implementation following the example here: https://quantopian.github.io/pyfolio/notebooks/bayesian/

import pyfolio as pf

# %%
stock_rets = pf.utils.get_symbol_rets('GOOG')

# %%
out_of_sample = stock_rets.index[-40]
pf.create_bayesian_tear_sheet(stock_rets, live_start_date=out_of_sample)
# Out:
# Running T model
# Auto-assigning NUTS sampler...
# Initializing NUTS using ADVI...
# Average Loss = -3,188.2:  15%|█▍        | 29384/200000 [00:20<01:58, 1442.53it/s]
# Convergence archived at 29500
# Interrupted at 29,500 [14%]: Average Loss = -572.1
# ...
# 100%|██████████| 2000/2000 [00:01<00:00, 1155.02it/s]
# Finished T model (required 144.20 seconds).
#
# Running BEST model
# Auto-assigning NUTS sampler...
# Initializing NUTS using ADVI...
# Average Loss = -3,292.3:  17%|█▋        | 34273/200000 [00:25<02:02, 1356.67it/s]
# Convergence archived at 34400
# Interrupted at 34,400 [17%]: Average Loss = -1,009.9
# 100%|██████████| 2500/2500 [00:06<00:00, 390.25it/s]
# Finished BEST model (required 73.29 seconds).
#
# Finished plotting Bayesian cone (required 0.14 seconds).
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# ...
